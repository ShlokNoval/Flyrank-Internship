# %% [markdown]
# # ML-02 â€” Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ShlokNoval/Flyrank-Internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** â€” each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# I am selecting **Lane 2: Refresh / Content Opportunity Scoring**. This lane builds naturally on the baseline we established in the starter notebooks. Instead of just identifying declining pages, it allows us to rank pages that represent the best return on an editor's timeâ€”those with enough traffic to matter, clear decay or underperformance, and a reasonable chance of recovery if refreshed.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one â€” typing sentences here breaks Run All.
# Out:
# # Executed

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# **Decision:** Which visible pages should a content editor review first for a refresh or update?
#
# **Action:** The content team will act by rewriting, expanding, or pruning the recommended pages.
#
# **Cost of a wrong call:** Wasted editor hours on pages that either didn't need a refresh or have no traffic to begin with, leading to missed opportunities on high-value decaying pages.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one â€” typing sentences here breaks Run All.
# Out:
# # Executed

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd
df = pd.read_csv('../../data/raw/content_refresh_anonymized.csv')
declining = len(df[df['trend_direction'] == 'down'])
high_value_decay = len(df[(df['trend_direction'] == 'down') & (df['impressions_90d'] > 1000) & (df['days_since_last_update'] > 180)])
print(f"Total declining pages in starter set: {declining}")
print(f"High-opportunity targets (>1000 impressions, stale >180 days, declining): {high_value_decay}")
print(f"A model can help prioritize this focused queue of {high_value_decay} pages.")
# Out:
# # Executed

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# **What I can claim:** We can observe which pages share characteristics with historically underperforming content and rank them as priority review candidates (a decision-support tool).
#
# **What I can't claim:** We cannot claim that a refresh will *cause* a recovery (we do not have causal proof), nor can we claim to have reverse-engineered Google's algorithm.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one â€” typing sentences here breaks Run All.
# Out:
# # Executed

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled â€” markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime â†’ Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` â€” then submit your repo URL on the card. Done.
