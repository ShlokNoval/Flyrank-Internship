# %% [markdown]
# # ML-05 â€” Feature Vector and Leakage/Privacy Check
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ShlokNoval/Flyrank-Internship/blob/main/work/notebooks/w03_feature_leakage_check.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** â€” each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Build the feature vector
#
# *Code that actually builds it â€” engineered features, categorical handling, fills.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one â€” typing sentences here breaks Run All.
# Out:
# # Executed

# %% [markdown]
# ## 2. Feature notes (meaning, missing, categorical, available-when?)
#
# *For each feature: what it means, how missing values are handled, and whether it exists BEFORE the moment you predict.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one â€” typing sentences here breaks Run All.
# Out:
# # Executed

# %% [markdown]
# ## 3. The leakage hunt
#
# *Attack your own features: label-derived columns, future windows, product flags. Show the test.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one â€” typing sentences here breaks Run All.
# Out:
# # Executed

# %% [markdown]
# ## 4. What I excluded and why
#
# *The list of fields you refused to use â€” with one line of why each.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one â€” typing sentences here breaks Run All.
# Out:
# # Executed

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled â€” markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime â†’ Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` â€” then submit your repo URL on the card. Done.
